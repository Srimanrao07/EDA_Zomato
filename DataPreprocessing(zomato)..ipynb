# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv(r"C:\Users\srima\OneDrive\Desktop\BRO\360digi\EDA\zomato.csv",encoding= "latin-1")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df["Restaurant ID"] = df["Restaurant ID"].astype(object)

# %%
df[["Country Code","Longitude","Latitude"]] = df[["Country Code","Longitude","Latitude"]].astype

# %%
df.dtypes
# Out:
# Restaurant ID            object
# Restaurant Name          object
# Country Code             object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude                object
# Latitude                 object
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df
# Out:
#      Restaurant ID           Restaurant Name  \
# 0          6317637          Le Petit Souffle
# 1          6304287          Izakaya Kikufuji
# 2          6300002    Heat - Edsa Shangri-La
# 3          6318506                      Ooma
# 4          6314302               Sambo Kojin
# ...            ...                       ...
# 9546       5915730              NamlÛ± Gurme
# 9547       5908749             Ceviz AÛôacÛ±
# 9548       5915807                     Huqqa
# 9549       5916112              Aôôk Kahve
# 9550       5927402  Walter's Coffee Roastery
#
#                                            Country Code              City  \
# 0     <bound method NDFrame.astype of       Country ...       Makati City
# 1     <bound method NDFrame.astype of       Country ...       Makati City
# 2     <bound method NDFrame.astype of       Country ...  Mandaluyong City
# 3     <bound method NDFrame.astype of       Country ...  Mandaluyong City
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
cat_imputer = SimpleImputer(strategy="most_frequent")

# %%
df[['Cuisines',"Price range",]] = cat_imputer.fit_transform(df[["Cuisines","Price range",]])

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df1 = df.drop(["Restaurant ID","Country Code","Longitude","Latitude","Switch to order menu"],axis=1)

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
from scipy.stats.mstats import winsorize

cleaned_d['Average Cost for two'] = winsorize(cleaned_d['Average Cost for two'], limits=[0.05, 0.05])

# %%
cleaned_d['Aggregate rating'] = winsorize(cleaned_d['Aggregate rating'], limits=[0.05, 0.05])

# %%
cleaned_d['Votes'] = winsorize(cleaned_d['Votes'], limits=[0.05, 0.05])

# %%
AV = AutoViz_Class()
# %matplotlib inline
dfte = AV.AutoViz(cleaned_d, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
               chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Out:
# Shape of your Data Set loaded: (6316, 16)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  4
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  3
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     16 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...

# %%
IOR = df["Average Cost for two"].quantile(0.75)-df["Average Cost for two"].quantile(0.25)
upperlimit = df["Average Cost for two"].quantile(0.75)+IOR
lowerlimit = df["Average Cost for two"].quantile(0.75)-IOR

# %%
upperlimit
# Out:
# 1150.0

# %%
lowerlimit
# Out:
# 250.0

# %%
IOR
# Out:
# 450.0

# %%
ot = df1[(df['Average Cost for two']< lowerlimit)|(df['Average Cost for two']>upperlimit)]

# %%
ot
# Out:
#           Restaurant Name             City        \
# 1             Izakaya Kikufuji       Makati City
# 2       Heat - Edsa Shangri-La  Mandaluyong City
# 3                         Ooma  Mandaluyong City
# 4                  Sambo Kojin  Mandaluyong City
# 6                   Buffet 101        Pasay City
# ...                        ...               ...
# 9546              NamlÛ± Gurme         ÛÁstanbul
# 9547             Ceviz AÛôacÛ±         ÛÁstanbul
# 9548                     Huqqa         ÛÁstanbul
# 9549              Aôôk Kahve         ÛÁstanbul
# 9550  Walter's Coffee Roastery         ÛÁstanbul
#
#                                                        Address                                                     \
# 1                                             Little Tokyo, 2277 Chino Roces Avenue, Legaspi Village, Makati City
# 2                                                        Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City
# ...

# %%
cleaned_d = df1[(df["Average Cost for two"]>=(lowerlimit))&(df["Average Cost for two"]<=upperlimit)]

# %%
cleaned_d
# Out:
#              Restaurant Name                 City        \
# 0                    Le Petit Souffle       Makati City
# 5                        Din Tai Fung  Mandaluyong City
# 9                            Locavore        Pasig City
# 10                   Silantro Fil-Mex        Pasig City
# 11    Mad Mark's Creamery & Good Eats        Pasig City
# ...                               ...               ...
# 9496              Remo's Maximilliano           Sandton
# 9509                  Butter Boutique           Colombo
# 9510               Carnival Ice Cream           Colombo
# 9516                    Burger's King           Colombo
# 9526                          Nusr-Et            Ankara
#
#                                              Address                                          \
# 0                    Third Floor, Century City Mall, Kalayaan Avenue, Poblacion, Makati City
# 5                    Ground Floor, Mega Fashion Hall, SM Megamall, Ortigas, Mandaluyong City
# ...
